# %% [markdown]
# # Setup

# %%
#clone if you haven't cloned the yolov5 repository
#!git clone https://github.com/ultralytics/yolov5
# %cd yolov5

#requirements installation
#!pip install -r requirements.txt
# Out:
# C:\Sinau\UAS\ML2\yolov5

# %%
import torch
import os
from IPython.display import Image, clear_output
import roboflow
from roboflow import Roboflow

location = os.getcwd()
print(location)
# Out:
# C:\Sinau\UAS\ML2\yolov5

# %%
print(f'setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else "CPU"})')
# Out:
# setup complete. Using torch 2.3.1+cpu (CPU)

# %%
# Set up Roboflow
rf = Roboflow(model_format='yolov5', notebook='ultralytics')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Set up Roboflow
# ----> 2 rf = Roboflow(model_format='yolov5', notebook='ultralytics')
#
# File ~\anaconda3\envs\UASElectronics\Lib\site-packages\roboflow\__init__.py:230, in Roboflow.__init__(self, api_key, model_format, notebook)
#     228 self.notebook = notebook
#     229 self.onboarding = False
# --> 230 self.auth()
#
# File ~\anaconda3\envs\UASElectronics\Lib\site-packages\roboflow\__init__.py:233, in Roboflow.auth(self)
#     232 def auth(self):
# --> 233     r = check_key(self.api_key, self.model_format, self.notebook)
#     235     if r == "onboarding":
#     236         self.onboarding = True
#
# File ~\anaconda3\envs\UASElectronics\Lib\site-packages\roboflow\__init__.py:22, in check_key(api_key, model, notebook, num_retries)
# ...

# %%
#set up envoriment
os.environ['dataset_directory'] = '../datasets'

# %%
# Download the dataset
rf = Roboflow(api_key="2ZCn6K3jRx5W5cLyB24S")
project = rf.workspace("abc-qqksz").project("electronic-ezdmf")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # Train the YOLOv5 Model

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data "C:/Sinau/UAS - Pembelajaran Mesin 2/datasets/Electronic-1/data.yaml" --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=C:/Sinau/UAS - Pembelajaran Mesin 2/datasets/Electronic-1/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Sinau\UAS': No such file or directory
# YOLOv5  2024-6-15 Python-3.11.9 torch-2.3.1+cpu CPU
#
# ...

# %% [markdown]
# # Show training results

# %%
# start tensorboard
#logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 1944), started 0:16:12 ago. (Use '!kill 1944' to kill it.)
#       <iframe id="tensorboard-frame-2899871667375ed2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2899871667375ed2");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# C:\Sinau\UAS - Pembelajaran Mesin 2

# %% [markdown]
# # Predictions

# %%
# !python detect.py --weights 'C:/Sinau/UAS - Pembelajaran Mesin 2/yolov5/runs/train/exp2/weights/best.pt' --img 416 --conf 0.2 --data "C:/Sinau/UAS - Pembelajaran Mesin 2/datasets/Electronic-1/images/test"
# Out:
# detect: weights=["'C:/Sinau/UAS", '-', 'Pembelajaran', 'Mesin', "2/yolov5/runs/train/exp2/weights/best.pt'"], source=data\images, data=C:/Sinau/UAS - Pembelajaran Mesin 2/datasets/Electronic-1/images/test, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Sinau\UAS': No such file or directory
# YOLOv5  2024-6-15 Python-3.11.9 torch-2.3.1+cpu CPU
#
# Traceback (most recent call last):
#   File "C:\Sinau\UAS - Pembelajaran Mesin 2\yolov5\detect.py", line 312, in <module>
#     main(opt)
#   File "C:\Sinau\UAS - Pembelajaran Mesin 2\yolov5\detect.py", line 307, in main
#     run(**vars(opt))
# ...
